# %% [markdown]
# Write your codes after `# Your code here` line inside each answer function.\
# Delete the `raise NotImplementedError` line in each answer function. \
# Name your file with your student ID and lab number, e.g. `6431234523-lab-03.ipynb`
#
# **DO NOT CHANGE THE FUNCTION NAME!!!**

# %% [markdown]
# ## Q1 (2 points)

# %% [markdown]
# Write a **reads** 3 coefficients, $a, b$ and $c$ of the equation $ax^2 + bx + c = 0$. Then, calculate two roots of this equation form the following formula.
#
# $$𝑥 = \frac{−𝑏± \sqrt{b^2-4ac}} {2a}$$
#
# **Print** out the roots of the equation. **If** there is no real solution, also print out the text `There is no real solution.`
#
# If there is only one root, you may print the root twice.

# %% [markdown]
# ### Example run #1
#
# - texts in **bold** are input from the keyboard
# - **⏎** indicates the cariage return symbol
#
# Enter coefficients a, b, c : **1,4,3⏎**\
# x = -1.0 , -3.0

# %% [markdown]
# ### Example run #2
#
# Enter coefficients a, b, c : **2.5,-8.7,2.1⏎**\
# x = 3.219053751558745 , 0.26094624844125425

# %% [markdown]
# ### Example run #3
#
# Enter coefficients a, b, c : **0,1,5⏎**\
# There is no real solution.

# %%
def answer_q1():
    # YOUR CODE HERE
    raise NotImplementedError

# %%
# You may debug your code by running this cell
answer_q1()

# %%
from unittest.mock import patch
from io import StringIO

def test_q1(inputs, outputs): 
    with patch('builtins.input', side_effect=inputs), patch('sys.stdout', new_callable=StringIO) as mock_stdout:
        answer_q1()
    
    assert mock_stdout.getvalue() == outputs, 'incorrect value: {}'.format(mock_stdout.getvalue())

# %%
test_q1(['1,4,3'],'x = -1.0 , -3.0\n')
test_q1(['2.5,-8.7,2.1'],'x = 3.219053751558745 , 0.26094624844125425\n')
test_q1(['1,1,-1'],'x = 0.6180339887498949 , -1.618033988749895\n')
test_q1(['1,2,1'],'x = -1.0 , -1.0\n')
test_q1(['2.3,-1.5,1.5'],'There is no real solution.\n')
test_q1(['1,1,1'],'There is no real solution.\n')
test_q1(['0,1,5'],'There is no real solution.\n')

print('Congrats!. You have passed all of the test cases.')

# %% [markdown]
# # Q2 (4 pts.)

# %% [markdown]
# Write a program that reads the PM2.5 concentration, $C$, (assume that the value is always between 0 and 500, inclusive) and
# - Calculate the air quality index ($I$, always an integer value) based on the US standard
# - Print out the air quality category
#
#
# |AQI Category | Index value | Concentration ($\mu g / m^3$) |
# |:-------------|:------------------:|:-----------------:|
# |Good | 0-50 | 0.0-12.0 |
# |Moderate| 51-100 | 12.1-35.4 |
# |Unhealthy for sensitive groups | 101-150 | 35.5-55.4 |
# |Unhealthy | 151-200 | 55.5-150.4 |
# |Very unhealthy | 201-300 | 150.5-250.4 |
# |Hazardous | 301-400 | 250.5-350.4 |
# |Hazardous | 401-500 | 350.5-500 |
#
#
# $$I={\frac {I_{high}-I_{low}}{C_{high}-C_{low}}}(C-C_{low})+I_{low}$$
#
# You may round any floating point to integer using `round` function
#
# E.g. `round(1.1)` returns `1` while `round(1.5)` returns `2`
#
#
# **Refereces**
# - https://en.wikipedia.org/wiki/Air_quality_index
# - https://www.epa.gov/sites/default/files/2016-04/documents/2012_aqi_factsheet.pdf

# %% [markdown]
# ### Example run #1
#
# Enter PM2.5 (microgram/cubic meter) : **10⏎**\
# Index 42, Good

# %% [markdown]
# ### Example run #2
#
# Enter PM2.5 (microgram/cubic meter) : **15⏎**\
# Index 57, Moderate

# %% [markdown]
# ### Example run #3
#
# Enter PM2.5 (microgram/cubic meter) : **41.3⏎**\
# Index 115, Unhealthy for sensitive groups

# %% [markdown]
# ### Example run #4
#
# Enter PM2.5 (microgram/cubic meter) : **55.7⏎**\
# Index 151, Unhealthy

# %% [markdown]
# ### Example run #5
#
# Enter PM2.5 (microgram/cubic meter) : **200⏎**\
# Index 250, Very unhealthy

# %% [markdown]
# ### Example run #6
#
# Enter PM2.5 (microgram/cubic meter) : **350.4⏎**\
# Index 400, Hazardous

# %%
def answer_q2():
    # YOUR CODE HERE
    raise NotImplementedError

# %%
# You may debug your code by running this cell
answer_q2()

# %%
from unittest.mock import patch
from io import StringIO

def test_q2(inputs, outputs): 
    with patch('builtins.input', side_effect=inputs), patch('sys.stdout', new_callable=StringIO) as mock_stdout:
        answer_q2()
    
    assert mock_stdout.getvalue() == outputs, 'incorrect value: {}'.format(mock_stdout.getvalue())

# %%
test_q2(['10'],'Index 42, Good\n')
test_q2(['15'],'Index 57, Moderate\n')
test_q2(['41.3'], 'Index 115, Unhealthy for sensitive groups\n')
test_q2(['55.7'], 'Index 151, Unhealthy\n')
test_q2(['200'], 'Index 250, Very unhealthy\n')
test_q2(['350.4'], 'Index 400, Hazardous\n')

print('Congrats!. You have passed all of the test cases.')

# %% [markdown]
# # Q3 (2 pts)

# %% [markdown]
#  Read the $x,y$ coordinate of a point and determine the location of the point in the figure
#
# ![area-image.png](data:image/png;base64,...)

# %% [markdown]
# ### Example run #1
#
# x,y : **10,20⏎**\
# (10,20) is in A

# %% [markdown]
# ### Example run #2
#
# x,y : **0,0⏎**\
# (0,0) is in B

# %% [markdown]
# ### Example run #3
#
# x,y : **1.5,10⏎**\
# (1.5,10) is in C

# %% [markdown]
# ### Example run #4
#
# x,y : **10,0⏎**\
# (10,0) is in D

# %%
def answer_q3():
    # YOUR CODE HERE
    raise NotImplementedError

# %%
# You may debug your code by running this cell
answer_q3()

# %%
from unittest.mock import patch
from io import StringIO

def test_q3(inputs, outputs): 
    with patch('builtins.input', side_effect=inputs), patch('sys.stdout', new_callable=StringIO) as mock_stdout:
        answer_q3()
    
    assert mock_stdout.getvalue() == outputs, 'incorrect value: {}'.format(mock_stdout.getvalue())

# %%
test_q3(['10,20'], '(10,20) is in A\n')
test_q3(['0,0'], '(0,0) is in B\n')
test_q3(['1.5,10'], '(1.5,10) is in C\n')
test_q3(['10,0'], '(10,0) is in D\n')

print('Congrats!. You have passed all of the test cases.')

# %% [markdown]
# # Q4 (2 pts.)

# %% [markdown]
# Write a program that reads Chula's student ID and verify that the ID is valid according to the following criteria
# - There are 10 digits
# - The first two digits are the enrollment year in B.E. (62-65)
# - The third digit from the left is either 0, 1, 3, 4, 7, or 8
# - The last two digits are the faculty code (21-40)

# %% [markdown]
# ### Example run #1
#
# Student ID : **6531234923⏎**\
# Valid

# %% [markdown]
# ### Example run #2
#
# Student ID : **65312349⏎**\
# Invalid

# %% [markdown]
# ### Example run #3
#
# Student ID : **6521234923⏎**\
# Invalid

# %% [markdown]
# ### Example run #4
#
# Student ID : **6531234944⏎**\
# Invalid

# %%
def answer_q4():
    # YOUR CODE HERE
    raise NotImplementedError

# %%
# You may debug your code by running this cell
answer_q4()

# %%
from unittest.mock import patch
from io import StringIO

def test_q4(inputs, outputs): 
    with patch('builtins.input', side_effect=inputs), patch('sys.stdout', new_callable=StringIO) as mock_stdout:
        answer_q4()
    
    assert mock_stdout.getvalue() == outputs, 'incorrect value: {}'.format(mock_stdout.getvalue())

# %%
test_q4(['6531234923'], 'Valid\n')
test_q4(['65312349'], 'Invalid\n')
test_q4(['6521234923'], 'Invalid\n')
test_q4(['6531234944'], 'Invalid\n')

print('Congrats!. You have passed all of the test cases.')
